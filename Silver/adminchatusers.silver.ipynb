# %%
from pyspark.sql.functions import col
df = spark.table("healthcarenew.bronze.adminchatusers")\
    .select("Adminchatusers_id", "AdminUserID", "ClassID", "chatusername", "AwardPoints", "CreatedDate","ModifiedDate")
df.write.format("delta").mode("overwrite").saveAsTable("healthcarenew.silver.adminchatusers")

# %%
df = spark.read.table("healthcarenew.silver.adminchatusers")
display(df)
