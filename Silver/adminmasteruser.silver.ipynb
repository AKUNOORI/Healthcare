# %%
from pyspark.sql.functions import *

df = spark.table("healthcarenew.bronze.adminmasteruser")\
    .select("*")
df.write.format("delta").mode("overwrite").saveAsTable("healthcarenew.silver.adminmasteruser")
