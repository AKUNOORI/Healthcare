# %% [markdown]
# Ingesting the data from the pp catalog into healthcareNew

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.ChatHistory AS
SELECT * FROM ppakcatalog.dbo.ChatHistory;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.admessages AS
SELECT * FROM ppakcatalog.dbo.admessages;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.adminchatusers AS
SELECT * FROM ppakcatalog.dbo.adminchatusers;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.adminmasteruser AS
SELECT * FROM ppakcatalog.dbo.adminmasteruser;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.awardcoins AS
SELECT * FROM ppakcatalog.dbo.awardcoins;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.chatblockedwords AS
SELECT * FROM ppakcatalog.dbo.chatblockedwords;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.classroomsetup AS
SELECT * FROM ppakcatalog.dbo.classroomsetup;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.classstudent AS
SELECT * FROM ppakcatalog.dbo.classstudent;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.configTable AS
SELECT * FROM ppakcatalog.dbo.`config-table`;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.favoriteactivity AS
SELECT * FROM ppakcatalog.dbo.favoriteactivity;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.gamefonts AS
SELECT * FROM ppakcatalog.dbo.gamefonts;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.gamemaster AS
SELECT * FROM ppakcatalog.dbo.gamemaster;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.gamequestions AS
SELECT * FROM ppakcatalog.dbo.gamequestions;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.gamesessionlines AS
SELECT * FROM ppakcatalog.dbo.gamesessionlines;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.gamesessions AS
SELECT * FROM ppakcatalog.dbo.gamesessions;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.medialibray AS
SELECT * FROM ppakcatalog.dbo.medialibray;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.messagelist AS
SELECT * FROM ppakcatalog.dbo.messagelist;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.popupmessages AS
SELECT * FROM ppakcatalog.dbo.popupmessages;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.ppsvlogmessages AS
SELECT * FROM ppakcatalog.dbo.pp_sv_log_messages;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.purchasedgame AS
SELECT * FROM ppakcatalog.dbo.purchasedgame;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.purchasedprofileavatar AS
SELECT * FROM ppakcatalog.dbo.purchasedprofileavatar;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.reportchatmessage AS
SELECT * FROM ppakcatalog.dbo.reportchatmessage;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.studentaccesscodelogs AS
SELECT * FROM ppakcatalog.dbo.studentaccesscodelogs;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.studentactionhistory AS
SELECT * FROM ppakcatalog.dbo.studentactionhistory;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.studentadaction AS
SELECT * FROM ppakcatalog.dbo.studentadaction;

# %%
# %sql
CREATE OR REPLACE TABLE healthcareNew.bronze.studentprofile AS
SELECT * FROM ppakcatalog.dbo.studentprofile;
