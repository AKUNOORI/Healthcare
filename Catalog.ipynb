# %%
# %sql
create catalog if not exists healthcareNew;

# %%
# %sql
create schema if not exists healthcareNew.bronze

# %%
# %sql
create schema if not exists healthcareNew.silver

# %%
# %sql
create schema if not exists healthcareNew.gold
